# %% [markdown]
# # Literature
#
# <table>
#   <tr>
#     <td align="center">
#       <a href="literature/paper1.pdf">
#         <img src="_static/paper1.png" width="200"><br>
#         Paper 1
#       </a>
#     </td>
#     <td align="center">
#       <a href="literature/paper2.pdf">
#         <img src="_static/paper2.png" width="200"><br>
#         Paper 2
#       </a>
#     </td>
#   </tr>
# </table>
