# %% [markdown]
# # Literature

# %%
from pathlib import Path
from urllib.parse import quote
from IPython.display import display, HTML

pdf_dir = Path("_static/literature_pdfs")
thumb_dir = Path("_static/literature_thumbs")

pdf_files = sorted(pdf_dir.glob("*.pdf"))

cards = []
for pdf_path in pdf_files:
    title = pdf_path.stem.replace("_", " ")
    
    pdf_href = f"../_static/literature_pdfs/{quote(pdf_path.name)}"
    img_src = f"../_static/literature_thumbs/{quote(pdf_path.stem)}.png"

    card = f"""
    <div style="width:220px; text-align:center; margin:15px;">
        <a href="{pdf_href}" target="_blank" style="text-decoration:none; color:inherit;">
            <img src="{img_src}" style="width:180px; border:1px solid #ccc; box-shadow:2px 2px 8px rgba(0,0,0,0.15);">
            <div style="margin-top:10px; font-size:14px; word-break:break-word;">{title}</div>
        </a>
    </div>
    """
    cards.append(card)

html = f"""
<div style="display:flex; flex-wrap:wrap; gap:10px;">
    {''.join(cards)}
</div>
"""

display(HTML(html))
# Out:
# <div style="display:flex; flex-wrap:wrap; gap:10px;">
#
#     <div style="width:220px; text-align:center; margin:15px;">
#         <a href="../literature/1-s2.0-S0012821X14000260-main.pdf" target="_blank" style="text-decoration:none; color:inherit;">
#             <img src="../_static/literature_thumbs/1-s2.0-S0012821X14000260-main.png" style="width:180px; border:1px solid #ccc; box-shadow:2px 2px 8px rgba(0,0,0,0.15);">
#             <div style="margin-top:10px; font-size:14px;">1-s2.0-S0012821X14000260-main</div>
#         </a>
#     </div>
#
#     <div style="width:220px; text-align:center; margin:15px;">
#         <a href="../literature/1-s2.0-S0012825213002018-main.pdf" target="_blank" style="text-decoration:none; color:inherit;">
#             <img src="../_static/literature_thumbs/1-s2.0-S0012825213002018-main.png" style="width:180px; border:1px solid #ccc; box-shadow:2px 2px 8px rgba(0,0,0,0.15);">
#             <div style="margin-top:10px; font-size:14px;">1-s2.0-S0012825213002018-main</div>
#         </a>
#     </div>
#
#     <div style="width:220px; text-align:center; margin:15px;">
#         <a href="../literature/1-s2.0-S1367912009001473-main.pdf" target="_blank" style="text-decoration:none; color:inherit;">
#             <img src="../_static/literature_thumbs/1-s2.0-S1367912009001473-main.png" style="width:180px; border:1px solid #ccc; box-shadow:2px 2px 8px rgba(0,0,0,0.15);">
#             <div style="margin-top:10px; font-size:14px;">1-s2.0-S1367912009001473-main</div>
#         </a>
#     </div>
#
#     <div style="width:220px; text-align:center; margin:15px;">
#         <a href="../literature/Geochemistry and petrogenesis of basaltic rocks from the Develidağ volcanic complex, Central Anatolia, Turkey.pdf" target="_blank" style="text-decoration:none; color:inherit;">
#             <img src="../_static/literature_thumbs/Geochemistry and petrogenesis of basaltic rocks from the Develidağ volcanic complex, Central Anatolia, Turkey.png" style="width:180px; border:1px solid #ccc; box-shadow:2px 2px 8px rgba(0,0,0,0.15);">
#             <div style="margin-top:10px; font-size:14px;">Geochemistry and petrogenesis of basaltic rocks from the Develidağ volcanic complex, Central Anatolia, Turkey</div>
#         </a>
#     </div>
#
#     <div style="width:220px; text-align:center; margin:15px;">
#         <a href="../literature/Interaction of Asthenospheric and Lithospheric Mantle  The Genesis of Calc-alkaline Volcanism at Erciyes Volcano  Central Anatolia  Turkey.pdf" target="_blank" style="text-decoration:none; color:inherit;">
#             <img src="../_static/literature_thumbs/Interaction of Asthenospheric and Lithospheric Mantle  The Genesis of Calc-alkaline Volcanism at Erciyes Volcano  Central Anatolia  Turkey.png" style="width:180px; border:1px solid #ccc; box-shadow:2px 2px 8px rgba(0,0,0,0.15);">
#             <div style="margin-top:10px; font-size:14px;">Interaction of Asthenospheric and Lithospheric Mantle  The Genesis of Calc-alkaline Volcanism at Erciyes Volcano  Central Anatolia  Turkey</div>
#         </a>
#     </div>
#
#     <div style="width:220px; text-align:center; margin:15px;">
#         <a href="../literature/jgeosci.362_Korkmaz (1).pdf" target="_blank" style="text-decoration:none; color:inherit;">
#             <img src="../_static/literature_thumbs/jgeosci.362_Korkmaz (1).png" style="width:180px; border:1px solid #ccc; box-shadow:2px 2px 8px rgba(0,0,0,0.15);">
#             <div style="margin-top:10px; font-size:14px;">jgeosci.362 Korkmaz (1)</div>
#         </a>
#     </div>
#
#     <div style="width:220px; text-align:center; margin:15px;">
#         <a href="../literature/s41467-017-01611-3.pdf" target="_blank" style="text-decoration:none; color:inherit;">
#             <img src="../_static/literature_thumbs/s41467-017-01611-3.png" style="width:180px; border:1px solid #ccc; box-shadow:2px 2px 8px rgba(0,0,0,0.15);">
#             <div style="margin-top:10px; font-size:14px;">s41467-017-01611-3</div>
#         </a>
#     </div>
#
#     <div style="width:220px; text-align:center; margin:15px;">
#         <a href="../literature/s41467-023-40147-7.pdf" target="_blank" style="text-decoration:none; color:inherit;">
#             <img src="../_static/literature_thumbs/s41467-023-40147-7.png" style="width:180px; border:1px solid #ccc; box-shadow:2px 2px 8px rgba(0,0,0,0.15);">
#             <div style="margin-top:10px; font-size:14px;">s41467-023-40147-7</div>
#         </a>
#     </div>
#
#     <div style="width:220px; text-align:center; margin:15px;">
#         <a href="../literature/s41467-024-52126-7.pdf" target="_blank" style="text-decoration:none; color:inherit;">
#             <img src="../_static/literature_thumbs/s41467-024-52126-7.png" style="width:180px; border:1px solid #ccc; box-shadow:2px 2px 8px rgba(0,0,0,0.15);">
#             <div style="margin-top:10px; font-size:14px;">s41467-024-52126-7</div>
#         </a>
#     </div>
#
# </div>
